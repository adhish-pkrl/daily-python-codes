# %%
#Data Cleaning
import pandas as pd
df = pd.read_csv('unclean_data.csv')
df
# Out:
#                                           property_name areaWithType  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# ...

# %%
#check missing cells
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
#check non-empty cells
df.notnull().sum()
# Out:
# property_name     4525
# areaWithType      4525
# square_feet       4525
# transaction       4421
# status            4524
# floor             4480
# furnishing        4185
# facing            3936
# description       3154
# price_per_sqft    4157
# price             4525
# dtype: int64

# %%
df.info() #view information about data
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_name   4525 non-null   str
#  1   areaWithType    4525 non-null   str
#  2   square_feet     4525 non-null   str
#  3   transaction     4421 non-null   str
#  4   status          4524 non-null   str
#  5   floor           4480 non-null   str
#  6   furnishing      4185 non-null   str
#  7   facing          3936 non-null   str
#  8   description     3154 non-null   str
#  9   price_per_sqft  4157 non-null   str
#  10  price           4525 non-null   str
# dtypes: str(11)
# memory usage: 389.0 KB

# %%
##view Duplicate Rows
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4520    False
# 4521    False
# 4522    False
# 4523    False
# 4524    False
# Length: 4525, dtype: bool

# %%
# df.dropna(axis= 1)

# %%
df.head(10)
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
# df.dropna(inplace =True)

# %%
df.head(10)
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
df.rename(columns = {"areaWithType":"Area Type"}, inplace=True)

# %%
df.head(5)
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished
# 3     New Property     Ready to Move  6 out of 14     Unfurnished
# 4  Orchid Fantasia      New Property  Unfurnished               2
#
#         facing                                        description  \
# ...

# %%
df.rename(columns= {"price_per_sqft": "Price @_sqft"}, inplace= True)

# %%
df.head()
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished
# 3     New Property     Ready to Move  6 out of 14     Unfurnished
# 4  Orchid Fantasia      New Property  Unfurnished               2
#
#         facing                                        description  \
# ...

# %%
# df.fillna(0)
# df.head(10)

# %%
df.head(10)
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
# df.fillna("0")
# df.head(10)

# %%
df.head(10)
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
df.head(10)
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
df.isnull().sum()
# df.head(10)
df.tail()
# Out:
#                                           property_name    Area Type  \
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet   transaction            status        floor   furnishing  \
# 4520   2000 sqft  New Property  Poss. by Dec '26  5 out of 12  Unfurnished
# 4521   3600 sqft  New Property  Poss. by Dec '25  5 out of 16  Unfurnished
# 4522   2250 sqft  New Property  Poss. by Dec '25  7 out of 13  Unfurnished
# 4523   3450 sqft  New Property     Ready to Move  7 out of 18  Unfurnished
# 4524   4500 sqft  New Property     Ready to Move  3 out of 12  Unfurnished
#
#             facing                                        description  \
# ...

# %%
df.head(10)
# Out:
#                                        property_name    Area Type square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
# 5  2 BHK Apartment for Sale in Anand Aspire, Jaha...   Super Area   1265 sqft
# 6              3 BHK Villa for Sale in Dindoli Surat  Carpet Area   1404 sqft
# 7                Office Space for Sale in Vesu Surat  Carpet Area    700 sqft
# 8  2 BHK Apartment for Sale in Orchid Gardenia, P...   Super Area   1180 sqft
# 9         2 BHK Apartment for Sale in Palanpur Surat  Carpet Area    720 sqft
#
#        transaction            status         floor      furnishing  \
# ...

# %%
df.fillna({"Price @_sqft": "₹2,500per_sqrft"})
df.tail()
# Out:
#                                           property_name    Area Type  \
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet   transaction            status        floor   furnishing  \
# 4520   2000 sqft  New Property  Poss. by Dec '26  5 out of 12  Unfurnished
# 4521   3600 sqft  New Property  Poss. by Dec '25  5 out of 16  Unfurnished
# 4522   2250 sqft  New Property  Poss. by Dec '25  7 out of 13  Unfurnished
# 4523   3450 sqft  New Property     Ready to Move  7 out of 18  Unfurnished
# 4524   4500 sqft  New Property     Ready to Move  3 out of 12  Unfurnished
#
#             facing                                        description  \
# ...

# %%
df.isnull().sum()
# Out:
# property_name       0
# Area Type           0
# square_feet         0
# transaction       104
# status              1
# floor              45
# furnishing        340
# facing            589
# description      1371
# Price @_sqft      368
# price               0
# dtype: int64

# %%
df.fillna({"Price @_sqft": "₹35000"}, inplace=True)
# Out:
#                                           property_name    Area Type  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# ...

# %%
df.isnull().sum()
# Out:
# property_name       0
# Area Type           0
# square_feet         0
# transaction       104
# status              1
# floor              45
# furnishing        340
# facing            589
# description      1371
# Price @_sqft        0
# price               0
# dtype: int64

# %%
df.tail()
# Out:
#                                           property_name    Area Type  \
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet   transaction            status        floor   furnishing  \
# 4520   2000 sqft  New Property  Poss. by Dec '26  5 out of 12  Unfurnished
# 4521   3600 sqft  New Property  Poss. by Dec '25  5 out of 16  Unfurnished
# 4522   2250 sqft  New Property  Poss. by Dec '25  7 out of 13  Unfurnished
# 4523   3450 sqft  New Property     Ready to Move  7 out of 18  Unfurnished
# 4524   4500 sqft  New Property     Ready to Move  3 out of 12  Unfurnished
#
#             facing                                        description  \
# ...

# %%
df.isnull().sum()
# Out:
# property_name       0
# Area Type           0
# square_feet         0
# transaction       104
# status              1
# floor              45
# furnishing        340
# facing            589
# description      1371
# Price @_sqft        0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_name  4525 non-null   str
#  1   Area Type      4525 non-null   str
#  2   square_feet    4525 non-null   str
#  3   transaction    4421 non-null   str
#  4   status         4524 non-null   str
#  5   floor          4480 non-null   str
#  6   furnishing     4185 non-null   str
#  7   facing         3936 non-null   str
#  8   description    3154 non-null   str
#  9   Price @_sqft   4525 non-null   str
#  10  price          4525 non-null   str
# dtypes: str(11)
# memory usage: 389.0 KB

# %%
new_df = df.drop(columns = ["property_name"])

# %%
new_df
# Out:
#         Area Type square_feet      transaction            status        floor  \
# 0     Carpet Area    644 sqft     New Property  Poss. by Oct '24  5 out of 10
# 1      Super Area   1278 sqft     New Property  Poss. by Jan '26  6 out of 14
# 2      Super Area   1173 sqft           Resale     Ready to Move  5 out of 13
# 3     Carpet Area    700 sqft     New Property     Ready to Move  6 out of 14
# 4      Super Area   1250 sqft  Orchid Fantasia      New Property  Unfurnished
# ...           ...         ...              ...               ...          ...
# 4520  Carpet Area   2000 sqft     New Property  Poss. by Dec '26  5 out of 12
# 4521   Super Area   3600 sqft     New Property  Poss. by Dec '25  5 out of 16
# 4522  Carpet Area   2250 sqft     New Property  Poss. by Dec '25  7 out of 13
# 4523  Carpet Area   3450 sqft     New Property     Ready to Move  7 out of 18
# 4524   Super Area   4500 sqft     New Property     Ready to Move  3 out of 12
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_name  4525 non-null   str
#  1   Area Type      4525 non-null   str
#  2   square_feet    4525 non-null   str
#  3   transaction    4421 non-null   str
#  4   status         4524 non-null   str
#  5   floor          4480 non-null   str
#  6   furnishing     4185 non-null   str
#  7   facing         3936 non-null   str
#  8   description    3154 non-null   str
#  9   Price @_sqft   4525 non-null   str
#  10  price          4525 non-null   str
# dtypes: str(11)
# memory usage: 389.0 KB

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Type     4525 non-null   str
#  1   square_feet   4525 non-null   str
#  2   transaction   4421 non-null   str
#  3   status        4524 non-null   str
#  4   floor         4480 non-null   str
#  5   furnishing    4185 non-null   str
#  6   facing        3936 non-null   str
#  7   description   3154 non-null   str
#  8   Price @_sqft  4525 non-null   str
#  9   price         4525 non-null   str
# dtypes: str(10)
# memory usage: 353.6 KB

# %%
dd = df.drop(columns=["square_feet"])

# %%
dd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_name  4525 non-null   str
#  1   Area Type      4525 non-null   str
#  2   transaction    4421 non-null   str
#  3   status         4524 non-null   str
#  4   floor          4480 non-null   str
#  5   furnishing     4185 non-null   str
#  6   facing         3936 non-null   str
#  7   description    3154 non-null   str
#  8   Price @_sqft   4525 non-null   str
#  9   price          4525 non-null   str
# dtypes: str(10)
# memory usage: 353.6 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4525 entries, 0 to 4524
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_name  4525 non-null   str
#  1   Area Type      4525 non-null   str
#  2   square_feet    4525 non-null   str
#  3   transaction    4421 non-null   str
#  4   status         4524 non-null   str
#  5   floor          4480 non-null   str
#  6   furnishing     4185 non-null   str
#  7   facing         3936 non-null   str
#  8   description    3154 non-null   str
#  9   Price @_sqft   4525 non-null   str
#  10  price          4525 non-null   str
# dtypes: str(11)
# memory usage: 389.0 KB

# %%
df.isnull().sum()
# Out:
# property_name       0
# Area Type           0
# square_feet         0
# transaction       104
# status              1
# floor              45
# furnishing        340
# facing            589
# description      1371
# Price @_sqft        0
# price               0
# dtype: int64

# %%
new_DF =df.fillna({"description": "Everything is good and Well"},inplace=True)

# %%
new_DF.isnull().sum()
# Out:
# property_name      0
# Area Type          0
# square_feet        0
# transaction      104
# status             1
# floor             45
# furnishing       340
# facing           589
# description        0
# Price @_sqft       0
# price              0
# dtype: int64

# %%
df.transaction.tail(20)
# Out:
# 4505    New Property
# 4506    New Property
# 4507    New Property
# 4508    New Property
# 4509    New Property
# 4510    New Property
# 4511    New Property
# 4512    New Property
# 4513    New Property
# 4514    New Property
# 4515    New Property
# 4516          Resale
# 4517          Resale
# 4518    New Property
# 4519    New Property
# 4520    New Property
# 4521    New Property
# 4522    New Property
# 4523    New Property
# 4524    New Property
# Name: transaction, dtype: str

# %%
df.drop()
