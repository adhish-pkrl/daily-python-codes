# %%
import pandas as pd
myset = {
    "name": ["adhish","Nirmal", "bishal"],
    "age": [19,21,22],
    "faculty": "BCA"
}
myvar = pd.DataFrame(myset)
print(myvar)
# Out:
#      name  age faculty
# 0  adhish   19     BCA
# 1  Nirmal   21     BCA
# 2  bishal   22     BCA

# %%
myvari = pd.Series(myset)
print(myvari)
# Out:
# name       [adhish, Nirmal, bishal]
# age                    [19, 21, 22]
# faculty                         BCA
# dtype: object

# %%
df = pd.read_csv('unclean_data.csv')
print(df)
# Out:
#                                           property_name areaWithType  \
# 0             2 BHK Apartment for Sale in Dindoli Surat  Carpet Area
# 1              2 BHK Apartment for Sale in Althan Surat   Super Area
# 2             2 BHK Apartment for Sale in Pal Gam Surat   Super Area
# 3        2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area
# 4     2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area
# ...                                                 ...          ...
# 4520  6 BHK Apartment for Sale in Millionaires Lifes...  Carpet Area
# 4521  4 BHK Apartment for Sale in Savan Superia, Alt...   Super Area
# 4522  5 BHK Apartment for Sale in Roongta Green Vall...  Carpet Area
# 4523  6 BHK Apartment for Sale in Cellestial Dreams,...  Carpet Area
# 4524  4 BHK Apartment for Sale in Roongta Green Vall...   Super Area
#
#      square_feet      transaction            status        floor  \
# 0       644 sqft     New Property  Poss. by Oct '24  5 out of 10
# ...

# %%
df.head()
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished
# 3     New Property     Ready to Move  6 out of 14     Unfurnished
# 4  Orchid Fantasia      New Property  Unfurnished               2
#
#         facing                                        description  \
# ...

# %%
df.columns

# %%
df.sample(2) #Shows the random Rows values

# %%
df.info()  #Shows the infor.. about DataFrame

# %%
# my_Sts = pd.DataFrame()
df.describe() #shows Statistical
# Out:
#                                  property_name areaWithType square_feet  \
# count                                     4525         4525        4525
# unique                                    1992            6        1399
# top     3 BHK Apartment for Sale in Vesu Surat   Super Area   1000 sqft
# freq                                        93         2599          77
#
#        transaction         status   floor   furnishing facing  \
# count         4421           4524    4480         4185   3936
# unique          38            138     222           78    176
# top         Resale  Ready to Move  Resale  Unfurnished   East
# freq          2197           3078     431         2322   1487
#
#                                               description    price_per_sqft  \
# count                                                3154              4157
# unique                                               2588              2134
# ...

# %%
df.shape #shows rows and Columns
# Out:
# (4525, 11)

# %%
df.columns #shows column names
# Out:
# Index(['property_name', 'areaWithType', 'square_feet', 'transaction', 'status',
#        'floor', 'furnishing', 'facing', 'description', 'price_per_sqft',
#        'price'],
#       dtype='str')

# %%
df.index #shows rows index
# Out:
# RangeIndex(start=0, stop=4525, step=1)

# %%
df.dtypes #data types
# Out:
# property_name     str
# areaWithType      str
# square_feet       str
# transaction       str
# status            str
# floor             str
# furnishing        str
# facing            str
# description       str
# price_per_sqft    str
# price             str
# dtype: object

# %%
len(df) #number of rows
# Out:
# 4525

# %%
df["property_name"] #gives value with duplicate values
# Out:
# 0               2 BHK Apartment for Sale in Dindoli Surat
# 1                2 BHK Apartment for Sale in Althan Surat
# 2               2 BHK Apartment for Sale in Pal Gam Surat
# 3          2 BHK Apartment for Sale in Jahangirabad Surat
# 4       2 BHK Apartment for Sale in Orchid Fantasia, P...
#                               ...
# 4520    6 BHK Apartment for Sale in Millionaires Lifes...
# 4521    4 BHK Apartment for Sale in Savan Superia, Alt...
# 4522    5 BHK Apartment for Sale in Roongta Green Vall...
# 4523    6 BHK Apartment for Sale in Cellestial Dreams,...
# 4524    4 BHK Apartment for Sale in Roongta Green Vall...
# Name: property_name, Length: 4525, dtype: str

# %%
df["property_name"].value_counts(4000) #without Duplicate value
# Out:
# property_name
# 3 BHK Apartment for Sale in Vesu Surat                              0.020552
# 3 BHK Apartment for Sale in Pal Surat                               0.016796
# 3 BHK Apartment for Sale in Palanpur Surat                          0.013702
# 4 BHK Apartment for Sale in Vesu Surat                              0.012376
# 2 BHK Apartment for Sale in Palanpur Surat                          0.011934
#                                                                       ...
# 4 BHK Apartment for Sale in Universal Homes, Adajan Surat           0.000221
# 4 BHK Apartment for Sale in D and M Elysium Avenue, Piplod Surat    0.000221
# 5 BHK Apartment for Sale in Sangini Arise, Bharthana Surat          0.000221
# 5 BHK Apartment for Sale in D and M Elysium Avenue, Piplod Surat    0.000221
# 6 BHK Apartment for Sale in Millionaires Lifestyle, Vesu Surat      0.000221
# Name: proportion, Length: 1992, dtype: float64

# %%
df["description"].value_counts()
# Out:
# description
# Multistorey apartment is available for sale. It is a good location property. Please contact for more details.Read more                                                                                                                                                                                                                                                                                                                                                                                                                                                                         35
# ...

# %%
df.iloc[2,4]
# Out:
# 'Ready to Move'

# %%
df.isnull()
# Out:
#       property_name  areaWithType  square_feet  transaction  status  floor  \
# 0             False         False        False        False   False  False
# 1             False         False        False        False   False  False
# 2             False         False        False        False   False  False
# 3             False         False        False        False   False  False
# 4             False         False        False        False   False  False
# ...             ...           ...          ...          ...     ...    ...
# 4520          False         False        False        False   False  False
# 4521          False         False        False        False   False  False
# 4522          False         False        False        False   False  False
# 4523          False         False        False        False   False  False
# 4524          False         False        False        False   False  False
#
#       furnishing  facing  description  price_per_sqft  price
# ...

# %%
df.notnull()
# Out:
#       property_name  areaWithType  square_feet  transaction  status  floor  \
# 0              True          True         True         True    True   True
# 1              True          True         True         True    True   True
# 2              True          True         True         True    True   True
# 3              True          True         True         True    True   True
# 4              True          True         True         True    True   True
# ...             ...           ...          ...          ...     ...    ...
# 4520           True          True         True         True    True   True
# 4521           True          True         True         True    True   True
# 4522           True          True         True         True    True   True
# 4523           True          True         True         True    True   True
# 4524           True          True         True         True    True   True
#
#       furnishing  facing  description  price_per_sqft  price
# ...

# %%
df["property_name"].unique() #view Unique value
# Out:
# <StringArray>
# [                       '2 BHK Apartment for Sale in Dindoli Surat',
#                          '2 BHK Apartment for Sale in Althan Surat',
#                         '2 BHK Apartment for Sale in Pal Gam Surat',
#                    '2 BHK Apartment for Sale in Jahangirabad Surat',
#       '2 BHK Apartment for Sale in Orchid Fantasia, Palanpur Surat',
#      '2 BHK Apartment for Sale in Anand Aspire, Jahangirabad Surat',
#                             '3 BHK Villa for Sale in Dindoli Surat',
#                             '  Office Space for Sale in Vesu Surat',
#       '2 BHK Apartment for Sale in Orchid Gardenia, Palanpur Surat',
#                        '2 BHK Apartment for Sale in Palanpur Surat',
#  ...
#         '3 BHK Apartment for Sale in KPM Terra Prime, Piplod Surat',
#        '4 BHK Apartment for Sale in Milestone Palacio, Athwa Surat',
#         '4 BHK Apartment for Sale in KPM Terra Prime, Piplod Surat',
# ...

# %%
df["price_per_sqft"].unique()
# Out:
# <StringArray>
# ['₹2,891 per sqft ', '₹3,551 per sqft ', '₹3,800 per sqft ',
#  '₹3,966 per sqft ', '₹3,600 per sqft ', '₹3,411 per sqft ',
#                 nan, '₹3,392 per sqft ', '₹3,751 per sqft ',
#  '₹3,200 per sqft ',
#  ...
#  '₹5,487 per sqft ', '₹7,300 per sqft ', '₹6,040 per sqft ',
#  '₹6,811 per sqft ', '₹5,930 per sqft ', '₹7,470 per sqft ',
#  '₹8,018 per sqft ', '₹8,512 per sqft ', '₹8,200 per sqft ',
#  '₹5,756 per sqft ']
# Length: 2135, dtype: str

# %%
df["square_feet"].nunique() #Count unique values
# Out:
# 1399

# %%
df["property_name"].nunique()
# Out:
# 1992

# %%
df["property_name"].value_counts() #Count occurrences of each value
# Out:
# property_name
# 3 BHK Apartment for Sale in Vesu Surat                              93
# 3 BHK Apartment for Sale in Pal Surat                               76
# 3 BHK Apartment for Sale in Palanpur Surat                          62
# 4 BHK Apartment for Sale in Vesu Surat                              56
# 2 BHK Apartment for Sale in Palanpur Surat                          54
#                                                                     ..
# 4 BHK Apartment for Sale in Universal Homes, Adajan Surat            1
# 4 BHK Apartment for Sale in D and M Elysium Avenue, Piplod Surat     1
# 5 BHK Apartment for Sale in Sangini Arise, Bharthana Surat           1
# 5 BHK Apartment for Sale in D and M Elysium Avenue, Piplod Surat     1
# 6 BHK Apartment for Sale in Millionaires Lifestyle, Vesu Surat       1
# Name: count, Length: 1992, dtype: int64
